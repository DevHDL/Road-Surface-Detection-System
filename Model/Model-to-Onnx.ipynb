# %% [markdown]
# ## YOLOv5 설치

# %%
# !git clone "https://github.com/ultralytics/yolov5"
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16836, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 16836 (delta 1), reused 6 (delta 0), pack-reused 16825
# Receiving objects: 100% (16836/16836), 15.57 MiB | 8.75 MiB/s, done.
# Resolving deltas: 100% (11550/11550), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %% [markdown]
# ## Train
# - data.yaml 위치 설정 및 내용 수정
# - model : yolov5n.pt

# %%
data_yaml = '/content/dataset/data.yaml'

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data {data_yaml} --weights yolov5n.pt
# Out:
# 2024-08-06 19:56:06.903110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-06 19:56:06.935302: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-06 19:56:06.945244: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## pytorch to onnx

# %%
model_path = '/content/yolov5/runs/train/exp2/weights/best.pt'
# !python export.py --weights {model_path} --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-350-g6096750f Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp2/weights/best.pt with output shape (1, 25200, 9) (3.7 MB)
#
# TorchScript: starting export with torch 2.3.1+cu121...
# TorchScript: export success ✅ 1.7s, saved as /content/yolov5/runs/train/exp2/weights/best.torchscript (7.2 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
